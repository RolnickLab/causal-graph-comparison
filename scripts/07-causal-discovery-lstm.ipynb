# %%
import numpy as np

import tigramite
from tigramite import data_processing as pp
from tigramite.toymodels import structural_causal_processes as toys
from tigramite import plotting as tp
from tigramite.pcmci import PCMCI

from tigramite.independence_tests.parcorr import ParCorr
from tigramite.independence_tests.gpdc import GPDC
from tigramite.independence_tests.cmiknn import CMIknn
from tigramite.independence_tests.cmisymb import CMIsymb

from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import StandardScaler
import pandas as pd
from matplotlib import pyplot as plt

from causal_graph_comparison.dim_reduction import subsample_outputs

# %%
N_MODES = 4
TAU_MAX = 5
LAT = 40
LON = 40
N_SAMPLES = 995

# %%
# Step 1: Load the data
lstm_output = np.load("../outputs/test_results-lstm-savar.npz")

# %%
outputs = lstm_output["outputs"]
targets = lstm_output["target"]
inputs = lstm_output["inputs"]

print("MLP output shape: ", outputs.shape)
print("MLP target shape: ", targets.shape)
print("MLP inputs shape: ", inputs.shape)
# Out:
# MLP output shape:  (50, 1600)
# MLP target shape:  (50, 1600)
# MLP inputs shape:  (5, 1600)

# %%
# Spatial subsampling of outputs for dimensionality reduction
subsampled_outputs = subsample_outputs(outputs, N_MODES)
subsampled_targets = subsample_outputs(targets, N_MODES)
# Out:
# Subsampled shape:  (50, 2, 2)
# Subsampled shape:  (50, 2, 2)

# %%
# Plot targets and outputs for all 4 quadrants
plt.figure(figsize=(10, 10))

for i in range(2):
    for j in range(2):
        plt.subplot(2, 2, i*2 + j + 1)
        test_targets = subsampled_targets[:, i, j]
        test_outputs = subsampled_outputs[:, i, j]
        
        plt.plot(test_targets, label="Target")
        plt.plot(test_outputs, label="Output")
        plt.title(f"Quadrant ({i},{j})")
        plt.legend()

plt.tight_layout()
plt.show()

print("Subsampled targets shape: ", subsampled_targets.shape)
print("Subsampled outputs shape: ", subsampled_outputs.shape)
# Out:
# Subsampled targets shape:  (50, 2, 2)
# Subsampled outputs shape:  (50, 2, 2)

# %%
# IMPROVED CAUSAL DISCOVERY - Use PCA to extract true modes
print("Extracting true modes using PCA...")

# Use original targets (not subsampled)
original_targets = targets.reshape(targets.shape[0], -1)  # (50, 1600)

# Extract 4 principal components (modes)
pca = PCA(n_components=4)
targets_pca = pca.fit_transform(original_targets)
print(f"PCA targets shape: {targets_pca.shape}")
print(f"Explained variance ratio: {pca.explained_variance_ratio_}")

# Use PCA components as our 4 modes
var_names = [f"mode_{i}" for i in range(4)]
dataframe = pp.DataFrame(targets_pca, var_names=var_names)

# %%
# STEP 4: Learn causal graph using PCMCI+

# flatten the data
subsampled_outputs = subsampled_outputs.reshape(subsampled_outputs.shape[0], -1)
subsampled_targets = subsampled_targets.reshape(subsampled_targets.shape[0], -1)

# Create variable names for the modes
var_names = [f"mode_{i}" for i in range(N_MODES)]
dataframe = pp.DataFrame(subsampled_targets, var_names=var_names)

# Initialize PCMCI+
pcmci = PCMCI(
    dataframe=dataframe,
    cond_ind_test=CMIknn(significance='shuffle_test'),
    verbosity=2
)


# Run PCMCI+
results = pcmci.run_pcmci(
    tau_max=TAU_MAX,  # Maximum time lag
    tau_min=1,
    pc_alpha=0.0001  # Significance level #TODO
)

n_gt_connections = 8 # TODO: get this from the GT causal graph in parameters csv file

# Extract results
graph = results['graph']
val_matrix = results['val_matrix']
p_matrix = results['p_matrix']

graph[
        results["val_matrix"]
        < np.abs(results["val_matrix"].flatten()[results["val_matrix"].flatten().argsort()[::-1][n_gt_connections - 1]])
    ] = ""

print(f"\nPCMCI+ Results:")
print(f"Graph shape: {graph.shape}")
print(f"Value matrix shape: {val_matrix.shape}")
print(f"P-value matrix shape: {p_matrix.shape}")

# Print the discovered links
print(f"\nDiscovered causal links:")
for i in range(len(var_names)):
    for j in range(len(var_names)):
        for tau in range(TAU_MAX):
            if graph[i, j, tau] != "":
                print(f"{var_names[i]} <-{graph[i, j, tau]}- {var_names[j]} (lag {tau+1})")
# Out:
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = cmi_knn
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.0001]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable mode_0
#
# Iterating through pc_alpha = [0.0001]:
#
# # pc_alpha = 0.0001 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link (mode_0 -1) -?> mode_0 (1/20):
#     Subset 0: () gives pval = 0.97200 / val = -0.003
#     Non-significance detected.
#
#     Link (mode_0 -2) -?> mode_0 (2/20):
#     Subset 0: () gives pval = 0.11400 / val =  0.138
#     Non-significance detected.
#
#     Link (mode_0 -3) -?> mode_0 (3/20):
#     Subset 0: () gives pval = 0.54200 / val =  0.056
#     Non-significance detected.
#
#     Link (mode_0 -4) -?> mode_0 (4/20):
#     Subset 0: () gives pval = 0.72600 / val =  0.038
#     Non-significance detected.
#
#     Link (mode_0 -5) -?> mode_0 (5/20):
#     Subset 0: () gives pval = 0.43400 / val =  0.062
#     Non-significance detected.
#
#     Link (mode_1 -1) -?> mode_0 (6/20):
#     Subset 0: () gives pval = 0.00000 / val =  0.314
#     No conditions of dimension 0 left.
#
#     Link (mode_1 -2) -?> mode_0 (7/20):
#     Subset 0: () gives pval = 0.80800 / val =  0.028
#     Non-significance detected.
#
#     Link (mode_1 -3) -?> mode_0 (8/20):
#     Subset 0: () gives pval = 0.75400 / val =  0.046
#     Non-significance detected.
#
#     Link (mode_1 -4) -?> mode_0 (9/20):
#     Subset 0: () gives pval = 0.82400 / val =  0.029
#     Non-significance detected.
#
#     Link (mode_1 -5) -?> mode_0 (10/20):
#     Subset 0: () gives pval = 0.37600 / val =  0.068
#     Non-significance detected.
#
#     Link (mode_2 -1) -?> mode_0 (11/20):
#     Subset 0: () gives pval = 0.45200 / val =  0.064
#     Non-significance detected.
#
#     Link (mode_2 -2) -?> mode_0 (12/20):
#     Subset 0: () gives pval = 0.13600 / val =  0.094
#     Non-significance detected.
#
#     Link (mode_2 -3) -?> mode_0 (13/20):
#     Subset 0: () gives pval = 0.19800 / val =  0.095
#     Non-significance detected.
#
#     Link (mode_2 -4) -?> mode_0 (14/20):
#     Subset 0: () gives pval = 0.89600 / val =  0.005
#     Non-significance detected.
#
#     Link (mode_2 -5) -?> mode_0 (15/20):
#     Subset 0: () gives pval = 0.05200 / val =  0.151
#     Non-significance detected.
#
#     Link (mode_3 -1) -?> mode_0 (16/20):
#     Subset 0: () gives pval = 0.65000 / val =  0.034
#     Non-significance detected.
#
#     Link (mode_3 -2) -?> mode_0 (17/20):
#     Subset 0: () gives pval = 0.86000 / val =  0.012
#     Non-significance detected.
#
#     Link (mode_3 -3) -?> mode_0 (18/20):
#     Subset 0: () gives pval = 0.08600 / val =  0.125
#     Non-significance detected.
#
#     Link (mode_3 -4) -?> mode_0 (19/20):
#     Subset 0: () gives pval = 0.26200 / val =  0.067
#     Non-significance detected.
#
#     Link (mode_3 -5) -?> mode_0 (20/20):
#     Subset 0: () gives pval = 0.72400 / val =  0.026
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable mode_0 has 1 link(s):
#         (mode_1 -1): max_pval = 0.00000, |min_val| =  0.314
#
# Algorithm converged for variable mode_0
#
# ## Variable mode_1
#
# Iterating through pc_alpha = [0.0001]:
#
# # pc_alpha = 0.0001 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link (mode_0 -1) -?> mode_1 (1/20):
#     Subset 0: () gives pval = 0.54800 / val =  0.059
#     Non-significance detected.
#
#     Link (mode_0 -2) -?> mode_1 (2/20):
#     Subset 0: () gives pval = 0.98200 / val = -0.030
#     Non-significance detected.
#
#     Link (mode_0 -3) -?> mode_1 (3/20):
#     Subset 0: () gives pval = 0.63200 / val =  0.036
#     Non-significance detected.
#
#     Link (mode_0 -4) -?> mode_1 (4/20):
#     Subset 0: () gives pval = 0.61200 / val =  0.054
#     Non-significance detected.
#
#     Link (mode_0 -5) -?> mode_1 (5/20):
#     Subset 0: () gives pval = 0.61200 / val =  0.045
#     Non-significance detected.
#
#     Link (mode_1 -1) -?> mode_1 (6/20):
#     Subset 0: () gives pval = 0.67800 / val =  0.034
#     Non-significance detected.
#
#     Link (mode_1 -2) -?> mode_1 (7/20):
#     Subset 0: () gives pval = 0.08000 / val =  0.142
#     Non-significance detected.
#
#     Link (mode_1 -3) -?> mode_1 (8/20):
#     Subset 0: () gives pval = 0.78400 / val =  0.026
#     Non-significance detected.
#
#     Link (mode_1 -4) -?> mode_1 (9/20):
#     Subset 0: () gives pval = 0.97400 / val = -0.012
#     Non-significance detected.
#
#     Link (mode_1 -5) -?> mode_1 (10/20):
#     Subset 0: () gives pval = 0.35000 / val =  0.073
#     Non-significance detected.
#
#     Link (mode_2 -1) -?> mode_1 (11/20):
#     Subset 0: () gives pval = 0.73000 / val =  0.032
#     Non-significance detected.
#
#     Link (mode_2 -2) -?> mode_1 (12/20):
#     Subset 0: () gives pval = 0.39200 / val =  0.058
#     Non-significance detected.
#
#     Link (mode_2 -3) -?> mode_1 (13/20):
#     Subset 0: () gives pval = 0.16000 / val =  0.089
#     Non-significance detected.
#
#     Link (mode_2 -4) -?> mode_1 (14/20):
#     Subset 0: () gives pval = 0.15000 / val =  0.105
#     Non-significance detected.
#
#     Link (mode_2 -5) -?> mode_1 (15/20):
#     Subset 0: () gives pval = 0.01600 / val =  0.188
#     Non-significance detected.
#
#     Link (mode_3 -1) -?> mode_1 (16/20):
#     Subset 0: () gives pval = 0.77200 / val =  0.016
#     Non-significance detected.
#
#     Link (mode_3 -2) -?> mode_1 (17/20):
#     Subset 0: () gives pval = 0.87800 / val =  0.018
#     Non-significance detected.
#
#     Link (mode_3 -3) -?> mode_1 (18/20):
#     Subset 0: () gives pval = 0.50800 / val =  0.053
#     Non-significance detected.
#
#     Link (mode_3 -4) -?> mode_1 (19/20):
#     Subset 0: () gives pval = 0.36400 / val =  0.056
#     Non-significance detected.
#
#     Link (mode_3 -5) -?> mode_1 (20/20):
#     Subset 0: () gives pval = 0.81600 / val =  0.007
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable mode_1 has 0 link(s):
#
# Algorithm converged for variable mode_1
#
# ## Variable mode_2
#
# Iterating through pc_alpha = [0.0001]:
#
# # pc_alpha = 0.0001 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link (mode_0 -1) -?> mode_2 (1/20):
#     Subset 0: () gives pval = 0.04000 / val =  0.155
#     Non-significance detected.
#
#     Link (mode_0 -2) -?> mode_2 (2/20):
#     Subset 0: () gives pval = 0.37800 / val =  0.055
#     Non-significance detected.
#
#     Link (mode_0 -3) -?> mode_2 (3/20):
#     Subset 0: () gives pval = 0.95200 / val =  0.001
#     Non-significance detected.
#
#     Link (mode_0 -4) -?> mode_2 (4/20):
#     Subset 0: () gives pval = 0.02200 / val =  0.164
#     Non-significance detected.
#
#     Link (mode_0 -5) -?> mode_2 (5/20):
#     Subset 0: () gives pval = 0.32000 / val =  0.064
#     Non-significance detected.
#
#     Link (mode_1 -1) -?> mode_2 (6/20):
#     Subset 0: () gives pval = 0.06200 / val =  0.131
#     Non-significance detected.
#
#     Link (mode_1 -2) -?> mode_2 (7/20):
#     Subset 0: () gives pval = 0.19200 / val =  0.083
#     Non-significance detected.
#
#     Link (mode_1 -3) -?> mode_2 (8/20):
#     Subset 0: () gives pval = 0.89600 / val =  0.000
#     Non-significance detected.
#
#     Link (mode_1 -4) -?> mode_2 (9/20):
#     Subset 0: () gives pval = 0.41600 / val =  0.052
#     Non-significance detected.
#
#     Link (mode_1 -5) -?> mode_2 (10/20):
#     Subset 0: () gives pval = 0.47400 / val =  0.052
#     Non-significance detected.
#
#     Link (mode_2 -1) -?> mode_2 (11/20):
#     Subset 0: () gives pval = 0.92000 / val = -0.005
#     Non-significance detected.
#
#     Link (mode_2 -2) -?> mode_2 (12/20):
#     Subset 0: () gives pval = 0.68400 / val =  0.056
#     Non-significance detected.
#
#     Link (mode_2 -3) -?> mode_2 (13/20):
#     Subset 0: () gives pval = 0.41800 / val =  0.052
#     Non-significance detected.
#
#     Link (mode_2 -4) -?> mode_2 (14/20):
#     Subset 0: () gives pval = 0.77000 / val =  0.036
#     Non-significance detected.
#
#     Link (mode_2 -5) -?> mode_2 (15/20):
#     Subset 0: () gives pval = 0.38000 / val =  0.058
#     Non-significance detected.
#
#     Link (mode_3 -1) -?> mode_2 (16/20):
#     Subset 0: () gives pval = 0.28200 / val =  0.088
#     Non-significance detected.
#
#     Link (mode_3 -2) -?> mode_2 (17/20):
#     Subset 0: () gives pval = 0.15400 / val =  0.117
#     Non-significance detected.
#
#     Link (mode_3 -3) -?> mode_2 (18/20):
#     Subset 0: () gives pval = 0.85600 / val =  0.002
#     Non-significance detected.
#
#     Link (mode_3 -4) -?> mode_2 (19/20):
#     Subset 0: () gives pval = 0.09800 / val =  0.142
#     Non-significance detected.
#
#     Link (mode_3 -5) -?> mode_2 (20/20):
#     Subset 0: () gives pval = 0.84200 / val =  0.024
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable mode_2 has 0 link(s):
#
# Algorithm converged for variable mode_2
#
# ## Variable mode_3
#
# Iterating through pc_alpha = [0.0001]:
#
# # pc_alpha = 0.0001 (1/1):
#
# Testing condition sets of dimension 0:
#
#     Link (mode_0 -1) -?> mode_3 (1/20):
#     Subset 0: () gives pval = 0.54000 / val =  0.051
#     Non-significance detected.
#
#     Link (mode_0 -2) -?> mode_3 (2/20):
#     Subset 0: () gives pval = 0.42000 / val =  0.064
#     Non-significance detected.
#
#     Link (mode_0 -3) -?> mode_3 (3/20):
#     Subset 0: () gives pval = 0.31200 / val =  0.062
#     Non-significance detected.
#
#     Link (mode_0 -4) -?> mode_3 (4/20):
#     Subset 0: () gives pval = 0.30200 / val =  0.064
#     Non-significance detected.
#
#     Link (mode_0 -5) -?> mode_3 (5/20):
#     Subset 0: () gives pval = 0.13000 / val =  0.112
#     Non-significance detected.
#
#     Link (mode_1 -1) -?> mode_3 (6/20):
#     Subset 0: () gives pval = 0.98400 / val = -0.010
#     Non-significance detected.
#
#     Link (mode_1 -2) -?> mode_3 (7/20):
#     Subset 0: () gives pval = 0.77200 / val =  0.021
#     Non-significance detected.
#
#     Link (mode_1 -3) -?> mode_3 (8/20):
#     Subset 0: () gives pval = 0.58000 / val =  0.035
#     Non-significance detected.
#
#     Link (mode_1 -4) -?> mode_3 (9/20):
#     Subset 0: () gives pval = 0.37200 / val =  0.064
#     Non-significance detected.
#
#     Link (mode_1 -5) -?> mode_3 (10/20):
#     Subset 0: () gives pval = 0.16600 / val =  0.095
#     Non-significance detected.
#
#     Link (mode_2 -1) -?> mode_3 (11/20):
#     Subset 0: () gives pval = 0.40600 / val =  0.046
#     Non-significance detected.
#
#     Link (mode_2 -2) -?> mode_3 (12/20):
#     Subset 0: () gives pval = 0.17400 / val =  0.114
#     Non-significance detected.
#
#     Link (mode_2 -3) -?> mode_3 (13/20):
#     Subset 0: () gives pval = 0.00400 / val =  0.195
#     Non-significance detected.
#
#     Link (mode_2 -4) -?> mode_3 (14/20):
#     Subset 0: () gives pval = 0.39400 / val =  0.074
#     Non-significance detected.
#
#     Link (mode_2 -5) -?> mode_3 (15/20):
#     Subset 0: () gives pval = 0.19600 / val =  0.082
#     Non-significance detected.
#
#     Link (mode_3 -1) -?> mode_3 (16/20):
#     Subset 0: () gives pval = 0.15800 / val =  0.114
#     Non-significance detected.
#
#     Link (mode_3 -2) -?> mode_3 (17/20):
#     Subset 0: () gives pval = 0.15200 / val =  0.089
#     Non-significance detected.
#
#     Link (mode_3 -3) -?> mode_3 (18/20):
#     Subset 0: () gives pval = 0.24200 / val =  0.083
#     Non-significance detected.
#
#     Link (mode_3 -4) -?> mode_3 (19/20):
#     Subset 0: () gives pval = 0.82200 / val =  0.029
#     Non-significance detected.
#
#     Link (mode_3 -5) -?> mode_3 (20/20):
#     Subset 0: () gives pval = 0.83800 / val =  0.014
#     Non-significance detected.
#
#     Sorting parents in decreasing order with
#     weight(i-tau->j) = min_{iterations} |val_{ij}(tau)|
#
# Updating parents:
#
#     Variable mode_3 has 0 link(s):
#
# Algorithm converged for variable mode_3
#
# ## Resulting lagged parent (super)sets:
#
#     Variable mode_0 has 1 link(s):
#         (mode_1 -1): max_pval = 0.00000, |min_val| =  0.314
#
#     Variable mode_1 has 0 link(s):
#
#     Variable mode_2 has 0 link(s):
#
#     Variable mode_3 has 0 link(s):
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = cmi_knn
# tau_min = 1
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
#         link (mode_0 -1) -?> mode_0 (1/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ (mode_1 -2) ]
#
#         link (mode_0 -2) -?> mode_0 (2/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ (mode_1 -3) ]
#
#         link (mode_0 -3) -?> mode_0 (3/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ (mode_1 -4) ]
#
#         link (mode_0 -4) -?> mode_0 (4/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ (mode_1 -5) ]
#
#         link (mode_0 -5) -?> mode_0 (5/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ (mode_1 -6) ]
#
#         link (mode_1 -1) -?> mode_0 (6/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -2) -?> mode_0 (7/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_1 -3) -?> mode_0 (8/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_1 -4) -?> mode_0 (9/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_1 -5) -?> mode_0 (10/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_2 -1) -?> mode_0 (11/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_2 -2) -?> mode_0 (12/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_2 -3) -?> mode_0 (13/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_2 -4) -?> mode_0 (14/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_2 -5) -?> mode_0 (15/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_3 -1) -?> mode_0 (16/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_3 -2) -?> mode_0 (17/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_3 -3) -?> mode_0 (18/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_3 -4) -?> mode_0 (19/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_3 -5) -?> mode_0 (20/20):
#         with conds_y = [ (mode_1 -1) ]
#         with conds_x = [ ]
#
#         link (mode_0 -1) -?> mode_1 (1/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -2) ]
#
#         link (mode_0 -2) -?> mode_1 (2/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -3) ]
#
#         link (mode_0 -3) -?> mode_1 (3/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -4) ]
#
#         link (mode_0 -4) -?> mode_1 (4/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -5) ]
#
#         link (mode_0 -5) -?> mode_1 (5/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -6) ]
#
#         link (mode_1 -1) -?> mode_1 (6/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -2) -?> mode_1 (7/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -3) -?> mode_1 (8/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -4) -?> mode_1 (9/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -5) -?> mode_1 (10/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -1) -?> mode_1 (11/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -2) -?> mode_1 (12/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -3) -?> mode_1 (13/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -4) -?> mode_1 (14/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -5) -?> mode_1 (15/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -1) -?> mode_1 (16/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -2) -?> mode_1 (17/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -3) -?> mode_1 (18/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -4) -?> mode_1 (19/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -5) -?> mode_1 (20/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_0 -1) -?> mode_2 (1/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -2) ]
#
#         link (mode_0 -2) -?> mode_2 (2/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -3) ]
#
#         link (mode_0 -3) -?> mode_2 (3/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -4) ]
#
#         link (mode_0 -4) -?> mode_2 (4/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -5) ]
#
#         link (mode_0 -5) -?> mode_2 (5/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -6) ]
#
#         link (mode_1 -1) -?> mode_2 (6/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -2) -?> mode_2 (7/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -3) -?> mode_2 (8/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -4) -?> mode_2 (9/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -5) -?> mode_2 (10/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -1) -?> mode_2 (11/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -2) -?> mode_2 (12/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -3) -?> mode_2 (13/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -4) -?> mode_2 (14/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -5) -?> mode_2 (15/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -1) -?> mode_2 (16/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -2) -?> mode_2 (17/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -3) -?> mode_2 (18/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -4) -?> mode_2 (19/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -5) -?> mode_2 (20/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_0 -1) -?> mode_3 (1/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -2) ]
#
#         link (mode_0 -2) -?> mode_3 (2/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -3) ]
#
#         link (mode_0 -3) -?> mode_3 (3/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -4) ]
#
#         link (mode_0 -4) -?> mode_3 (4/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -5) ]
#
#         link (mode_0 -5) -?> mode_3 (5/20):
#         with conds_y = [ ]
#         with conds_x = [ (mode_1 -6) ]
#
#         link (mode_1 -1) -?> mode_3 (6/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -2) -?> mode_3 (7/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -3) -?> mode_3 (8/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -4) -?> mode_3 (9/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_1 -5) -?> mode_3 (10/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -1) -?> mode_3 (11/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -2) -?> mode_3 (12/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -3) -?> mode_3 (13/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -4) -?> mode_3 (14/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_2 -5) -?> mode_3 (15/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -1) -?> mode_3 (16/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -2) -?> mode_3 (17/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -3) -?> mode_3 (18/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -4) -?> mode_3 (19/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
#         link (mode_3 -5) -?> mode_3 (20/20):
#         with conds_y = [ ]
#         with conds_x = [ ]
#
# ## Significant links at alpha = 0.05:
#
#     Variable mode_0 has 2 link(s):
#         (mode_1 -1): pval = 0.00000 | val =  0.314
#         (mode_2 -5): pval = 0.02800 | val =  0.121
#
#     Variable mode_1 has 1 link(s):
#         (mode_2 -5): pval = 0.01600 | val =  0.188
#
#     Variable mode_2 has 0 link(s):
#
#     Variable mode_3 has 1 link(s):
#         (mode_2 -3): pval = 0.00400 | val =  0.195
#
# PCMCI+ Results:
# Graph shape: (4, 4, 6)
# Value matrix shape: (4, 4, 6)
# P-value matrix shape: (4, 4, 6)
#
# Discovered causal links:
# mode_1 <--->- mode_0 (lag 2)
# mode_2 <--->- mode_3 (lag 4)

# %%
# Step 5: Analyze mode relationships


print(f"\nStep 5: Analyzing mode relationships...")

# Calculate correlations between modes
correlations = np.corrcoef(subsampled_targets.reshape(-1, 4).T)

print(f"\nCorrelation matrix between modes:")
print(pd.DataFrame(correlations, index=var_names, columns=var_names))

# Count causal links per mode
print(f"\nCausal link counts per mode:")
for i, mode in enumerate(var_names):
    incoming = np.sum(graph[i, :, :] != "")
    outgoing = np.sum(graph[:, i, :] != "")
    print(f"{mode}: {incoming} incoming, {outgoing} outgoing links")
# Out:
# Step 5: Analyzing mode relationships...
#
# Correlation matrix between modes:
#           mode_0    mode_1    mode_2    mode_3
# mode_0  1.000000  0.022352  0.075715  0.006253
# mode_1  0.022352  1.000000  0.018645  0.319321
# mode_2  0.075715  0.018645  1.000000  0.029872
# mode_3  0.006253  0.319321  0.029872  1.000000
#
# Causal link counts per mode:
# mode_0: 0 incoming, 2 outgoing links
# mode_1: 1 incoming, 1 outgoing links
# mode_2: 3 incoming, 0 outgoing links
# mode_3: 0 incoming, 1 outgoing links

# %%
# Step 6: Plot causal graph
print(f"\nStep 6: Plotting causal graph...")

# Plot graph for each lag
tp.plot_time_series_graph(
    graph = graph,
    val_matrix=val_matrix,
    figsize=(8, 8),
    node_size=0.05,
    var_names=var_names,
    link_colorbar_label='PC')

plt.tight_layout()
# plt.savefig("causal_graph_example.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# Step 6: Plotting causal graph...
